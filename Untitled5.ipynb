# %%
st="Basit is a good husband of Sawera"
print(st)
# Out:
# Basit is a good husband of Sawera

# %%
st="Basit is a good husband of Sawera"
print(len(st))       # find the length
# Out:
# 33

# %%
st="Basit is a good husband of Sawera"
print(st[0:33])
# Out:
# Basit is a good husband of Sawera

# %%
st="Basit is a good husband of Sawera"
print(st[::2])
# Out:
# Bsti  odhsado aea

# %%
st="Basit is a good husband of Sawera"
print(st[::555])
# Out:
# B

# %%
st="Sawera"
print(st[1:4])
# Out:
# awe

# %%
st="Sawera"
print(st[-5:-2])
# Out:
# awe

# %%
st="Sawera"
print(st[::-1])
# Out:
# arewaS

# %%
st="Basit is a good husband of Sawera"
print(type(st))
# Out:
# <class 'str'>

# %%
st="Basit is a good husband of Sawera"
print(len(st))
# Out:
# 33

# %%
st="Basit is a good husband of Sawera"
print(st.isalnum())
# Out:
# False

# %%
st="102564863"
print(st.isalnum())
# Out:
# True

# %%
st="BasitisagoodhusbandofSawera"
print(st.isalpha())
# Out:
# True

# %%
st="Basit is a good husband of Sawera"
print(st.isalpha())
# Out:
# False

# %%
st="Basit is a good husband of Sawera"
print(st.find("is"))
# Out:
# 6

# %%
st="Basit is a good husband of Sawera"
print(st.count("a"))
# Out:
# 5

# %%
st="basit is a good husband of Sawera"
print(st.endswith("sawera"))
# Out:
# False

# %%
st="basit is a good husband of Sawera"
print(st.endswith("Sawera"))
# Out:
# True

# %%
st="basit is a good husband of Sawera"
print(st.capitalize())
# Out:
# Basit is a good husband of sawera

# %%
st="Basit is a good husband of Sawera"
print(st.lower())
# Out:
# basit is a good husband of sawera

# %%
st="basit is a good husband of Sawera"
print(st.upper())
# Out:
# BASIT IS A GOOD HUSBAND OF SAWERA

# %%
st="basit is a good husband of Sawera"
print(st.replace("good","bad"))
# Out:
# basit is a bad husband of Sawera

# %%
st="basit is a good husband of Sawera"
print(st.count(""))
# Out:
# 34

# %%
num=["basit", "ali", "javed", 56, 60]
print(num)
# Out:
# ['basit', 'ali', 'javed', 56, 60]

# %%
num=["basit", "ali", "javed", 56, 60]
print(len(num))
# Out:
# 5

# %%
num=["basit", "ali", "javed", 56, 60]
num.append(45)
print(num)
# Out:
# ['basit', 'ali', 'javed', 56, 60, 45]

# %%
num=["basit", "ali", "javed", 56, 60]
num.insert(1,5)
print(num)
# Out:
# ['basit', 5, 'ali', 'javed', 56, 60]

# %%
num=["basit", "ali", "javed", 56, 60]
num.remove(56)
print(num)
# Out:
# ['basit', 'ali', 'javed', 60]

# %%
num=["basit", "ali", "javed", 56, 60]
num.pop()
print(num)
# Out:
# ['basit', 'ali', 'javed', 56]

# %%
num=["basit", "ali", "javed", 56, 60]
print(num[::-1])
# Out:
# [60, 56, 'javed', 'ali', 'basit']

# %%
num=[2, 64, 70, 56, 60]
num.sort()
print(num)
# Out:
# [2, 56, 60, 64, 70]

# %%
num=[2, 64, 70, 56, 60]
print(max(num))
# Out:
# 70

# %%
num=[2, 64, 70, 56, 60]
print(min(num))
# Out:
# 2

# %%
num=[2, 64, 70, 56, 60]
num.clear()
print(num)
# Out:
# []

# %%
num=[2, 64," 70", 56, 60]

print(type(num))
# Out:
# <class 'list'>

# %%
num=[2, 64, 70, 56, 60]
num.extend([622, 464, 6458])
print(num)
# Out:
# [2, 64, 70, 56, 60, 622, 464, 6458]

# %%
tup=(45, 252, 55)
print(tup)
# Out:
# (45, 252, 55)

# %%
tup=(1,)
print(tup)
# Out:
# (1,)

# %%
tup=(1)
print(tup)
# Out:
# 1

# %%
tup=(1, 654, 8886, "Basit")
print(list(tup))
# Out:
# [1, 654, 8886, 'Basit']

# %%
li=["basit",56]
li2=["ali"]
print(cmp(li, li2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-05d6bafbe177> in <module>
#       1 li=["basit",56]
#       2 li2=["ali"]
# ----> 3 print(cmp(li, li2))
#
# NameError: name 'cmp' is not defined

# %%
stock_price_1 = [50.23]
stock_price_2 = [75.14]

print(cmp(stock_price_1, stock_price_2))
print(cmp(stock_price_1, stock_price_1))
print(cmp(stock_price_2, stock_price_1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-f7617a857f8f> in <module>
#       2 stock_price_2 = [75.14]
#       3
# ----> 4 print(cmp(stock_price_1, stock_price_2))
#       5 print(cmp(stock_price_1, stock_price_1))
#       6 print(cmp(stock_price_2, stock_price_1))
#
# NameError: name 'cmp' is not defined
