# %%
print("Hello Word")
# Out:
# Hello Word

# %%
print("I am Basit Ali & I am Programmer.")
# Out:
# I am Basit Ali & I am Programmer.

# %%
#This is single line Comment
print("I am Basit Ali & I am Programmer.")
# Out:
# I am Basit Ali & I am Programmer.

# %%
'''
Multi-line
Comment
'''
print("Basit Ali")
# Out:
# Basit Ali

# %%
#line break
print("Hi! I am Programmer \n Yesssssss")
# Out:
# Hi! I am Programmer
#  Yesssssss

# %%
#Insert Tab
print("Hi! I am Programmer \t Yesssssss")
# Out:
# Hi! I am Programmer 	 Yesssssss

# %%
#Insert Backspace
print("Hi! I am Programmer \b Yesssssss")
# Out:
# Yesssssss

# %%
#Insert Backslash
print("Hi! I am Programmer \\ Yesssssss")
# Out:
# Hi! I am Programmer \ Yesssssss

# %%
#Insert carriage return
print("Hi! I am Programmer \r Yesss")
# Out:
#  Yesss

# %%
#Insert form feed
print("Hi! I am Programmer \f Yesssssss")
# Out:
# Hi! I am Programmer  Yesssssss
