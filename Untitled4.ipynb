# %%
print("Enter the name" )
inm=input()
print("Your name is",inm)
# Out:
# Enter the name
# Basit Ali
# Your name is Basit Ali

# %%
print("Enter the name" )
inm=input()
print("Your name is",inm)
# Out:
# Enter the name
# afsdfs
# Your name is afsdfs

# %%
print(10*"Basit Ali\t")
# Out:
# Basit Ali	Basit Ali	Basit Ali	Basit Ali	Basit Ali	Basit Ali	Basit Ali	Basit Ali	Basit Ali	Basit Ali
