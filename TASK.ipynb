# %%
# Search data from the dictionary and display the screen.

d1 = {"Data":"Collection of information", "Best Book":"Holy Quran", "Mobile":"Electronic Device", "Movie":"Shershah"}
search = input("Find : ")
print(d1[search])
# Out:
# Find : Movie
# Shershah

# %%
# Take input the age from the user and the if the age is greater than 18 display msg you can drive otherwise not.

age = int(input("Enter the age: "))
if age > 18:
    print("You can Drive the car.")
elif age < 18:
    print("You cannot Drive the car.")
else:
    print("First! I will check your Drive. ")
# Out:
# Enter the age: 41
# You can Drive the car.

# %%
# Take input the age from the user and the range of age is 7 to 100.
age = int(input("Enter the Age : "))
if age >= 7 and age <= 100:
    print("You can use Computer.")
else:
    print("You cannot use Computer.")
# Out:
# Enter the Age : 101
# You cannot use Computer.

# %%
# Faulty calculator          ( 45*3=555, 56+9 = 77, 56/6= 4 )

num1 = int(input("Enter the First Number : "))
op = (input("Enter the Operators(+,-,/,* %): "))
num2 = int(input("Enter the Second Number : "))
if num1 == 56 and num2 == 9 and op == '+':
    print("Result is = 77")
elif num1 == 45 and num2 == 3 and op == '*':
    print("Result is = 555")
elif num1 == 56 and num2 == 6 and op == '/':
    print("Result is = 4")
elif op == '+':
    print("Result is = ",num1 + num2)
elif op == '-':
    print("Result is = ",num1 - num2)
elif op == '*':
    print("Result is = ",num1 * num2)
elif op == '/':
    print("Result is = ",num1 / num2)
elif op == '%':
    print("Result is = ",num1 % num2)
else:
    print("Invalid Operator")
# Out:
# Enter the First Number : 4
# Enter the Operators(+,-,/,* %): -
# Enter the Second Number : 6
# Result is =  -2
