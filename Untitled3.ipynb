# %%
print("Pakistan Zindabad")
# Out:
# Pakistan Zindabad

# %%
var="Pakistan "
var1="Zindabad"
print(var+var1)
# Out:
# Pakistan Zindabad

# %%
var=65
var1=32
print(var+var1)
# Out:
# 97

# %%
var="basit ali "
var1= 32
print(var+str(var1))
# Out:
# basit ali 32

# %%
var="1000"
var1="2000"
print(var+var1)
# Out:
# 10002000

# %%
var="1000"
var1="2000"
print(int(var)+int(var1))
# Out:
# 3000

# %%
print("Enter the number : " )
inm=input()
print("You enter the number")
# Out:
# Enter the number :
# 5
# You enter the number

# %%
print("Enter the first number:")
first_num=input()      # as a String store
print("Enter the second number:")
second_num=input()     # as a String store
print("The Sum of two number is",int(first_num)+int(second_num))
# Out:
# Enter the first number:
# 45
# Enter the second number:
# 45
# The Sum of two number is  90

# %%
var="Pakistan Zindabad"
var1=36
var2=20.1222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222
print(type(var))
print(type(var1))
print(type(var2))
print(type(var3))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# type() Function in Python:
harry = "40" 
demo = 55.5  
demo3 = type(demo) #It will return data type as float 
print(demo3)
# Out:
# <class 'float'>

# %%
var1 = "My Name is "
var2 = "Harry"
var3 = var1+var2+" & I am a Good Boy."
print(var1+var2) # It will give output 'My Name is Harry'
print(var3)
# Out:
# My Name is Harry
# My Name is Harry & I am a Good Boy.

# %%
print("Enter the name" )
inm=input()
print("Your name is",inm)

# %%
print("Enter the name" )
inm=input()
print("Your name is",inm)

# %%
print("Enter the name" )
inmm=input()
print("Your name is",inmm)
